# %%
# !pip install --upgrade seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\aspire\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\aspire\anaconda3\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aspire\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aspire\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aspire\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aspire\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aspire\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\aspire\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import warnings
warnings.filterwarnings("ignore", category=Futurewarnings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 import warnings
# ----> 2 warnings.filterwarnings("ignore", category=Futurewarnings)
#
# NameError: name 'Futurewarnings' is not defined

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme(style="darkgrid")

# %%
tips.to_csv("tips_dataset.csv", index=False)
import pandas as pd

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Aspire'

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", size="size", palette="deep")
plt.title("Scatterplot of Total Bill vs Tip")
plt.show()

# %%
sns.lineplot(data=tips, x= 'size', y='total_bill', hue='sex', marker='o')
plt.title("Lineplot of Total Bill vs Size")
plt.show()

# %%
sns.lineplot(data=tips, x= 'size', y='total_bill', hue='sex',ci=None, markers='o')
plt.title("Lineplot of Total Bill vs Size")
plt.show()
# Out:
# C:\Users\Aspire\AppData\Local\Temp\ipykernel_2120\4000830819.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=tips, x= 'size', y='total_bill', hue='sex',ci=None, markers='o')

# %%
tips.columns

# %%
sns.barplot(data=tips, x='day', y='total_bill', hue = 'sex', palette='muted')
plt.title("barplot of Total Bill by Day")
plt.show()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# BOXPLOT

# %%
sns.boxenplot(data=tips, x='day', y='tip', hue='smoker', palette='dark')
plt.title("boxplot of Tips by Day and Smoker Status")
plt.show()

# %%
# violon plot

# %%
sns.violinplot(data=tips, x='day', y='total_bill', hue='time', split=True, palette='pastel')
plt.title("Violin Plot of Total Bill by Day and Time")
plt.show()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.countplot(data=tips, x='day', hue='smoker', palette='dark')
plt.title("Count Plot of Days by smoker status")
plt.show()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.regplot(data=tips, x='total_bill', y='tip', scatter_kws={'s':50}, line_kws={'color':'red'})
plt.title("Regression Plot of Total Bill vs Tip")
plt.show()

# %%
sns.histplot(data=tips, x='total_bill', bins=20, kde=True, color='darkgreen')
plt.title("Histogram of Total Bill with KDE")
plt.show()

# %%
sns.pairplot(tips, hue='sex', vars=["total_bill", "tip", "size"], palette='husl')
plt.subtitle("Pair plot:numeric variables by gender", y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 sns.pairplot(tips, hue='sex', vars=["total_bill", "tip", "size"], palette='husl')
# ----> 2 plt.subtitle("Pair plot:numeric variables by gender", y=1.02)
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'

# %%
import seaborn as sns

# %%
tips.columns

# %%
sns.catplot(data=tips, x='day', y='tip', hue='sex', kind='point', palette='husl')
plt.title("catplot(point):Tips by day and gender") 
plt.show()

# %%
sns.jointplot(data=tips, x= 'total_bill', y='tip', kind='scatter', hue='smoker',color='purple', palette='dark')
plt.subtitle("jointplot: Total Bill vs Tip", y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 2
#       1 sns.jointplot(data=tips, x= 'total_bill', y='tip', kind='scatter', hue='smoker',color='purple', palette='dark')
# ----> 2 plt.subtitle("jointplot: Total Bill vs Tip", y=1.02)
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'

# %%
g = sns.FacetGrid(tips, col='time', row='smoker', margin_titles=True).map(sns.histplot, 'total_bill', bins=20, kde=True).add_legend()

g

# %%
sns.stripplot(data=tips, x='day', y='tip', hue='sex', jitter=True, palette='dark')
plt.title("strip plot: tips by data and gender")
plt.show()

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex', fill=True, palette='tab10')
plt.title("kde plot:Total bill density by gender")
plt.show()

# %%
# we plot all the graphs using seaborn -- statical visualization
